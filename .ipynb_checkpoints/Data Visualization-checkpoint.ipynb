# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.to_csv('Tips.csv')

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.set_style('white')
import warnings
warnings.filterwarnings('ignore')

# %%
sns.distplot(tips['total_bill'], color = 'red')
plt.title('Histogram')
plt.show()

# %%
sns.distplot(tips['total_bill'], color = 'red', kde = False)
plt.title('Histogram')
plt.show()

# %%
plt.figure(figsize=(10,5))
sns.distplot(tips['total_bill'], color = 'red', kde = False)
plt.title('Histogram')
plt.xlabel('Total Bill')
plt.ylabel('The Density')
plt.show()

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips)

# %%
tips[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000

# %%
tips['day'].unique()
sun = tips[tips['day'] == 'Sun']

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = sun, hue = 'sex')

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind='kde')

# %%
plt.scatter(x = 'total_bill', y = 'tip', c= 'r', data = tips, marker = 'x', alpha = 0.50)

# %%
sns.pairplot(tips)

# %%
sns.pairplot(tips, hue = 'sex', palette='Paired')

# %%
sns.rugplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.kdeplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='Density'>

# %%
plt.figure(figsize = (10,5))
sns.barplot(x= 'day', y = 'total_bill', data = tips)
# Out:
# <AxesSubplot:xlabel='day', ylabel='total_bill'>

# %%
sns.countplot(tips['sex'])
# Out:
# <AxesSubplot:xlabel='sex', ylabel='count'>

# %%
sns.boxplot(y = 'sex', x = 'total_bill', data = tips, orient = 'h')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='sex'>

# %%
sns.boxplot(tips['total_bill'])
# Out:
# <AxesSubplot:xlabel='total_bill'>

# %%
sns.violinplot(x = 'sex', y = 'total_bill', data = tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.stripplot(x = 'sex', y = 'total_bill', data = tips)
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
sns.swarmplot(x = 'sex', y = 'total_bill', data = tips, palette='magma')
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
sns.swarmplot(x = 'sex', y = 'total_bill', data = tips, palette='magma')
#plt.show()
sns.violinplot(x = 'sex', y = 'total_bill', data = tips)
# Out:
# <AxesSubplot:xlabel='sex', ylabel='total_bill'>

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), cmap='viridis')
# Out:
# <AxesSubplot:>

# %%
sns.clustermap(tips.corr())

# %%
sns.heatmap(pd.crosstab(index = tips['sex'], columns = tips['day'], values=tips['tip'], aggfunc='mean'))
# Out:
# <AxesSubplot:xlabel='day', ylabel='sex'>

# %%
titanic = sns.load_dataset('titanic')

# %%
sns.heatmap(titanic.isnull(), cbar= False, yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
import numpy as np

# %%
a = np.random.randint(0,100,20)
b = np.random.randint(1000,10000,20)

# %%
np.corrcoef(a,b)
# Out:
# array([[ 1.        , -0.07753885],
#        [-0.07753885,  1.        ]])

# %%
sns.heatmap(np.corrcoef(a,b))
# Out:
# <AxesSubplot:>

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tips[['total_bill', 'tip']].corr()
# Out:
#             total_bill       tip
# total_bill    1.000000  0.675734
# tip           0.675734  1.000000
